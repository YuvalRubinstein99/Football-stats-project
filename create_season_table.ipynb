# %%
import pandas as pd
import numpy as np
from difflib import SequenceMatcher

# %%
def find_closest_name(name, other_names):
    checked = []
    for other_name in other_names:
        if other_name in checked:
            continue
        if(isinstance(other_name, float)):
            continue
        if name in other_name:
            return other_name

# %%
def find_most_similar_name(target_name, names_list, threshold=0.25):
    similarities = [(other_name, SequenceMatcher(None, target_name, other_name).ratio()) for other_name in names_list]
    most_similar_name, similarity_score = max(similarities, key=lambda x: x[1])
    
    if similarity_score >= threshold:
        print('found player '+most_similar_name+" with a score of "+str(similarity_score))
        return most_similar_name, similarity_score
    else:
        print("didn't find", target_name)
        return None, None

def find_player(player_name, club_name,  df, attributes):
    #first we filter by club name
    temp = df[df['Club Name'] == club_name]

    #Now we find the player
    sim_name, full_score = find_most_similar_name(player_name, temp['Full Name'])
    sim_nickname, short_score = find_most_similar_name(player_name, temp['Known As'])
    if sim_name: # there is a full name
        ## if there is a nickname we have to check
        if sim_nickname and full_score > short_score:
            return temp[temp['Full Name'] == sim_name].iloc[0][attributes]
        elif sim_nickname:
            return temp[temp['Known As'] == sim_nickname].iloc[0][attributes]
        return temp[temp['Full Name'] == sim_name].iloc[0][attributes]
    if sim_nickname: # if there is a nickname but no full name
        return temp[temp['Known As'] == sim_nickname].iloc[0][attributes]
    return None


def ratings_col(df, att_df):
    '''
    puts for every player their 'Overall', 'Age', 'Height(in cm)', 'Weight(in kg)'
    for each player i we will have the column
    HomePlayeri (if the player is on the home team)
    AwayPlayeri (if the player is on the away team)
    and we will use the home_team_name or away_team_name and the full name as the key (we will use find_player(player_name, club_name,  df, attributes))
    '''

    attributes = [ 'Overall']
    # Iterate through each player column
    for i in range(1, 12):
        home_col = f'HomePlayer{i}'
        away_col = f'AwayPlayer{i}'
        if home_col in df.columns or away_col in df.columns:
            # Add columns for home team players
            for att in attributes:
                df[home_col + "_" + att] = df.apply(
                    lambda row: 0 if pd.isna(row[home_col]) else
                    (find_player(row[home_col], row['home_team_name'], att_df, attributes)[att]
                    if find_player(row[home_col], row['home_team_name'], att_df, attributes) is not None else None),
                    axis=1
                )
            

            # Add columns for away team players
            for att in attributes:
                df[away_col + "_" + att] = df.apply(
                    lambda row: 0 if pd.isna(row[away_col]) else
                    (find_player(row[away_col], row['away_team_name'], att_df, attributes)[att]
                    if find_player(row[away_col], row['away_team_name'], att_df, attributes) is not None else None),
                    axis=1
                )
def replace_nas(df):
    '''
    gets df, goes to the Age column and replaces None with 18, and replaces Weight(in kg) and Height(in cm) with the mean, and overall with the min value
    '''

    # 'Dribbling Total', 'Pace Total', 'Defending Total', 'Shooting Total', 'Physicality Total', 'Passing Total' our new fatures
    attributes = ['Overall']
    # First, deal with the None values
    for i in range(1,12):
        home_col = f'HomePlayer{i}'
        away_col = f'AwayPlayer{i}'
        if home_col in df.columns:
            for att  in attributes: 
                non_zero_col = df[home_col+'_'+att].replace(0, None)
                df[home_col+'_'+att].fillna(non_zero_col.min())
        if away_col in df.columns:

            for att  in attributes: 
                non_zero_col = df[away_col+'_'+att].replace(0, None)
                df[away_col+'_'+att].fillna(non_zero_col.min())
           

    # Dealing with zero values
    for i in range(1, 12):
        home_col = f'HomePlayer{i}'
        away_col = f'AwayPlayer{i}'
        if home_col in df.columns:
            for att in attributes:
                df[home_col+"_"+att].replace(0, None, inplace=True)
        if away_col in df.columns:
            for att in attributes:
                df[away_col+"_"+att].replace(0, None, inplace=True)
          

def set_season_cols(columns, season):
    for c in season.columns:
        for att in ['Overall']:
            if att in c:
                print(c)
                columns.append(c)
def create_csv(df, columns, name):
    df[columns].to_csv(name)

def pipeline(matches_df, ratings_df):
    
    att_list = ['Overall']
    for att in att_list:
        if att not in ratings_df.columns:
            print('fix',att)
    

    # Sanity Check
    ratings_df = ratings_df[['Full Name', 'Club Name', 'Known As']+ att_list]
    ratings_col(matches_df, ratings_df)
    replace_nas(matches_df)
    final_cols = ['home_score', 'home_team_name', 'away_score', 'away_team_name','home_GD_prior', 'away_GD_prior', 'home_Points_prior', 'away_Points_prior',
                   'home_GD_form', 'home_Points_form', 'away_GD_form','away_Points_form', 'B365A', 'B365D', 'B365H',
                  'Matchweek']
    set_season_cols(final_cols, matches_df)
    return matches_df

# %%
leagues = ['laliga','seriea','bl']
years = ['1415','1516','1617', '1718','1819','1920','2021','2122','2223']

# #loading all the data to one data per 

for year in years:
    df = []
    for league in leagues:
        curr = pd.read_csv(league+"_data/"+league+year+"_form_bets.csv")
        if league == 'ucl':
            curr.rename(columns={'Matchweek' : "Stage"}, inplace=True)
        curr['league'] = league

        df.append(curr)
    curr_df = pd.concat(df,ignore_index=True)
    
    curr_df.drop(["Unnamed: 0.2","Unnamed: 0.1"], axis=1, inplace=True)
    curr_players = pd.read_csv('players_'+year[-2:]+'.csv')

    ### make sure we are only in eu


    ############ Now we will do the same thing we did in the players and matches pipeline but only take the fifa ratings
    curr_players.rename(columns={'long_name' : 'Full Name',
                          'short_name': "Known As", 'height_cm':'Height(in cm)',
                          'weight_kg' : 'Weight(in kg)',
                          'age' : 'Age','club_name' :"Club Name",
                          'overall' : 'Overall', 'dribbling' : 'Dribbling Total',
                          'pace' : 'Pace Total', 'defending' : "Defending Total" ,
                          "shooting" : 'Shooting Total', 'physic' : 'Physicality Total',
                          'passing' : "Passing Total"},inplace=True)
    #first we need to check the team names
    fifa_team_names = curr_players['Club Name'].values
    checked = []
    not_found = []
    names_fix = {'Celta Vigo': 'RC Celta de Vigo'
                 , 'Atlético Madrid': 'Atlético de Madrid'
                 , 'Bayern Munich': 'FC Bayern München'
                 , 'Eint Frankfurt': 'Eintracht Frankfurt'
                 , 'Gladbach': 'Borussia Mönchengladbach',
                 'Sporting Gijón':'Real Sporting de Gijón'}
    for team in curr_df['home_team_name'].values:
        
        if (team not in fifa_team_names and team not in checked) and team not in names_fix.keys():
            checked.append(team)
            #print(team+" not found")
            
            alt = find_closest_name(team, fifa_team_names)
            if(alt):
                print(team+" can be replaced with "+alt)
                names_fix[team] = alt
            else:
                not_found.append(team)

    print(not_found)
    for key in names_fix.keys():
        curr_players['Club Name'].replace(names_fix[key],key, inplace=True)
    season = pipeline(curr_df, curr_players)
    season.to_csv("season_data/season"+year+'.csv')
# Out:
# C:\Users\Yuval\AppData\Local\Temp\ipykernel_106068\1333768337.py:16: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   curr_players = pd.read_csv('players_'+year[-2:]+'.csv')
# Málaga can be replaced with Málaga CF
# Granada can be replaced with Granada CF
# Sevilla can be replaced with Sevilla FC
# Almería can be replaced with Unión Deportiva Almería
# Eibar can be replaced with SD Eibar
# Barcelona can be replaced with FC Barcelona
# Levante can be replaced with Levante Unión Deportiva
# Real Madrid can be replaced with Real Madrid CF
# Getafe can be replaced with Getafe CF
# Valencia can be replaced with Valencia CF
# Córdoba can be replaced with Córdoba CF
# Athletic Club can be replaced with Athletic Club de Bilbao
# Espanyol can be replaced with RCD Espanyol de Barcelona
# Villarreal can be replaced with Villarreal CF
# La Coruña can be replaced with Deportivo de La Coruña
# Elche can be replaced with Elche CF
# Chievo can be replaced with Chievo Verona
# Milan can be replaced with AC Milan
# Torino can be replaced with Torino F.C.
# Sassuolo can be replaced with U.S. Sassuolo Calcio
# Udinese can be replaced with Udinese Calcio
# Sampdoria can be replaced with U.C. Sampdoria
# Hoffenheim can be replaced with TSG Hoffenheim
# Köln can be replaced with 1. FC Köln
# Dortmund can be replaced with Borussia Dortmund
# Paderborn 07 can be replaced with SC Paderborn 07
# Augsburg can be replaced with FC Augsburg
# Wolfsburg can be replaced with VfL Wolfsburg
# Stuttgart can be replaced with VfB Stuttgart
# Leverkusen can be replaced with Bayer 04 Leverkusen
# Werder Bremen can be replaced with SV Werder Bremen
# Schalke 04 can be replaced with FC Schalke 04
# Mainz 05 can be replaced with 1. FSV Mainz 05
# Freiburg can be replaced with Sport-Club Freiburg
# []
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Stole Dimitrievski with a score of 1.0
# found player S. Dimitrievski with a score of 0.8484848484848485
# found player Stole Dimitrievski with a score of 1.0
# found player S. Dimitrievski with a score of 0.8484848484848485
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Jesús Fernández Collado with a score of 0.35714285714285715
# found player Jesús with a score of 1.0
# found player Jesús Fernández Collado with a score of 0.35714285714285715
# found player Jesús with a score of 1.0
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# C:\Users\Yuval\AppData\Local\Temp\ipykernel_106068\1333768337.py:55: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   curr_players['Club Name'].replace(names_fix[key],key, inplace=True)
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Germán Darío Lux with a score of 0.7692307692307693
# found player G. Lux with a score of 0.625
# found player Germán Darío Lux with a score of 0.7692307692307693
# found player G. Lux with a score of 0.625
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Sergio Rico González with a score of 0.7096774193548387
# found player Sergio Rico with a score of 1.0
# found player Sergio Rico González with a score of 0.7096774193548387
# found player Sergio Rico with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Germán Darío Lux with a score of 0.7692307692307693
# found player G. Lux with a score of 0.625
# found player Germán Darío Lux with a score of 0.7692307692307693
# found player G. Lux with a score of 0.625
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Jesús Fernández Collado with a score of 0.35714285714285715
# found player Jesús with a score of 1.0
# found player Jesús Fernández Collado with a score of 0.35714285714285715
# found player Jesús with a score of 1.0
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Keylor Navas Gamboa with a score of 0.7741935483870968
# found player K. Navas with a score of 0.7
# found player Keylor Navas Gamboa with a score of 0.7741935483870968
# found player K. Navas with a score of 0.7
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Manuel Herrera Yagüe with a score of 0.75
# found player Manu Herrera with a score of 1.0
# found player Manuel Herrera Yagüe with a score of 0.75
# found player Manu Herrera with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Jesús Fernández Collado with a score of 0.35714285714285715
# found player Jesús with a score of 1.0
# found player Jesús Fernández Collado with a score of 0.35714285714285715
# found player Jesús with a score of 1.0
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Germán Darío Lux with a score of 0.7692307692307693
# found player G. Lux with a score of 0.625
# found player Germán Darío Lux with a score of 0.7692307692307693
# found player G. Lux with a score of 0.625
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# didn't find Toño
# found player Toño with a score of 1.0
# didn't find Toño
# found player Toño with a score of 1.0
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Manuel Herrera Yagüe with a score of 0.75
# found player Manu Herrera with a score of 1.0
# found player Manuel Herrera Yagüe with a score of 0.75
# found player Manu Herrera with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# didn't find Toño
# found player Toño with a score of 1.0
# didn't find Toño
# found player Toño with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Keylor Navas Gamboa with a score of 0.7741935483870968
# found player K. Navas with a score of 0.7
# found player Keylor Navas Gamboa with a score of 0.7741935483870968
# found player K. Navas with a score of 0.7
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Roberto Fernández Alvarellos with a score of 0.4
# found player Roberto with a score of 1.0
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Rubén Iván Martínez Andrade with a score of 0.3125
# found player Rubén with a score of 1.0
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Eñaut Zubikarai Goñi with a score of 0.8571428571428571
# found player Zubikarai with a score of 0.75
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Cristian Darío Álvarez with a score of 0.8421052631578947
# found player C. Álvarez with a score of 0.6923076923076923
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Oier Olazábal Paredes with a score of 0.7647058823529411
# found player Oier with a score of 0.47058823529411764
# found player Oier Olazábal Paredes with a score of 0.7647058823529411
# found player Oier with a score of 0.47058823529411764
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Vicente Guaita Panadero with a score of 0.7567567567567568
# found player Guaita with a score of 0.6
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Gerónimo Rulli with a score of 1.0
# found player G. Rulli with a score of 0.6363636363636364
# found player Gerónimo Rulli with a score of 1.0
# found player G. Rulli with a score of 0.6363636363636364
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Diego Mariño Villar with a score of 0.7741935483870968
# found player Diego Mariño with a score of 1.0
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Iker Casillas Fernández with a score of 0.7222222222222222
# found player Casillas with a score of 0.7619047619047619
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Carlos Idriss Kameni with a score of 0.7878787878787878
# found player C. Kameni with a score of 0.7272727272727273
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Sergio Álvarez Conde with a score of 0.8235294117647058
# found player Sergi Gómez with a score of 0.64
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Xabier Iruretagoiena Aranzamendi with a score of 0.5454545454545454
# found player Irureta with a score of 0.7368421052631579
# found player Julián Cuesta Díaz with a score of 0.8387096774193549
# found player Julián with a score of 0.631578947368421
# found player Julián Cuesta Díaz with a score of 0.8387096774193549
# found player Julián with a score of 0.631578947368421
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Oier Olazábal Paredes with a score of 0.7647058823529411
# found player Oier with a score of 0.47058823529411764
# found player Oier Olazábal Paredes with a score of 0.7647058823529411
# found player Oier with a score of 0.47058823529411764
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# found player Claudio Andrés Bravo Muñoz with a score of 0.6666666666666666
# found player C. Bravo with a score of 0.6666666666666666
# didn't find Toño
# found player Toño with a score of 1.0
# didn't find Toño
# found player Toño with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Gerónimo Rulli with a score of 1.0
# found player G. Rulli with a score of 0.6363636363636364
# found player Gerónimo Rulli with a score of 1.0
# found player G. Rulli with a score of 0.6363636363636364
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# found player Diego Alves with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Jordi Codina Rodríguez with a score of 0.7058823529411765
# found player Codina with a score of 0.6666666666666666
# found player Jordi Codina Rodríguez with a score of 0.7058823529411765
# found player Codina with a score of 0.6666666666666666
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Benoît Trémoulinas with a score of 0.36363636363636365
# found player Beto with a score of 1.0
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Juan Carlos Martín Corral with a score of 0.6111111111111112
# found player Juan Carlos with a score of 1.0
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Przemysław Tytoń with a score of 1.0
# found player P. Tytoń with a score of 0.5833333333333334
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Miguel Ángel Moyá Rumbo with a score of 0.85
# found player Moyá with a score of 0.38095238095238093
# found player Gerónimo Rulli with a score of 1.0
# found player G. Rulli with a score of 0.6363636363636364
# found player Gerónimo Rulli with a score of 1.0
# found player G. Rulli with a score of 0.6363636363636364
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Sergio Asenjo Andrés with a score of 0.7878787878787878
# found player Sergio Asenjo with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Fabricio Martín Agosto Ramírez with a score of 0.42105263157894735
# found player Fabricio with a score of 1.0
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Gorka Iraizoz Moreno with a score of 0.7878787878787878
# found player Iraizoz with a score of 0.7
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Francisco Casilla Cortés with a score of 0.5555555555555556
# found player Kiko Casilla with a score of 1.0
# found player Diego Alves Carreira with a score of 0.7096774193548387
# ...
# found player Juanfran with a score of 1.0
# found player Eneko Bóveda Altube with a score of 0.7741935483870968
# found player Bóveda with a score of 0.6666666666666666
# found player Eneko Bóveda Altube with a score of 0.7741935483870968
# found player Bóveda with a score of 0.6666666666666666
# found player Sergio Ramos García with a score of 0.7741935483870968
# found player Sergio Ramos with a score of 1.0
# found player Sergio Ramos García with a score of 0.7741935483870968
# found player Sergio Ramos with a score of 1.0
# found player Allan-Roméo Nyom with a score of 0.7692307692307693
# found player A. Nyom with a score of 0.7058823529411765
# found player Allan-Roméo Nyom with a score of 0.7692307692307693
# found player A. Nyom with a score of 0.7058823529411765
# found player Hugo Mallo Novegil with a score of 0.7142857142857143
# found player Hugo Mallo with a score of 1.0
# found player Hugo Mallo Novegil with a score of 0.7142857142857143
# found player Hugo Mallo with a score of 1.0
# found player Weligton Róbson Pena de Oliveira with a score of 0.6938775510204082
# found player Weligton with a score of 0.64
# found player Weligton Róbson Pena de Oliveira with a score of 0.6938775510204082
# found player Weligton with a score of 0.64
# found player Joaquín Navarro Jiménez with a score of 0.5142857142857142
# found player Ximo Navarro with a score of 1.0
# found player Joaquín Navarro Jiménez with a score of 0.5142857142857142
# found player Ximo Navarro with a score of 1.0
# found player Rubén Ramiro Pastor with a score of 0.2608695652173913
# found player Tito with a score of 1.0
# found player Rubén Ramiro Pastor with a score of 0.2608695652173913
# found player Tito with a score of 1.0
# found player Benoît Trémoulinas with a score of 1.0
# found player B. Trémoulinas with a score of 0.8125
# found player Benoît Trémoulinas with a score of 1.0
# found player B. Trémoulinas with a score of 0.8125
# found player Ivan Rakitić with a score of 1.0
# found player I. Rakitić with a score of 0.8181818181818182
# found player Ivan Rakitić with a score of 1.0
# found player I. Rakitić with a score of 0.8181818181818182
# found player Rúben Miguel Nunes Vezo with a score of 0.6060606060606061
# found player Rúben Vezo with a score of 1.0
# found player Rúben Miguel Nunes Vezo with a score of 0.6060606060606061
# found player Rúben Vezo with a score of 1.0
# found player David Rodríguez Lombán with a score of 0.7058823529411765
# found player Lombán with a score of 0.6666666666666666
# found player David Rodríguez Lombán with a score of 0.7058823529411765
# found player Lombán with a score of 0.6666666666666666
# found player Juan Carlos Real Ruiz with a score of 0.41379310344827586
# found player Juanfran with a score of 1.0
# found player Juan Carlos Real Ruiz with a score of 0.41379310344827586
# found player Juanfran with a score of 1.0
# found player Mario Gaspar Pérez Martínez with a score of 0.6153846153846154
# found player Mario Gaspar with a score of 1.0
# found player Mario Gaspar Pérez Martínez with a score of 0.6153846153846154
# found player Mario Gaspar with a score of 1.0
# found player Aymeric Laporte with a score of 1.0
# found player A. Laporte with a score of 0.72
# found player Aymeric Laporte with a score of 1.0
# found player A. Laporte with a score of 0.72
# found player Diego Roberto Godín Leal with a score of 0.6285714285714286
# found player D. Godín with a score of 0.7368421052631579
# found player Diego Roberto Godín Leal with a score of 0.6285714285714286
# found player D. Godín with a score of 0.7368421052631579
# found player Gerard Piqué Bernabéu with a score of 0.7272727272727273
# found player Piqué with a score of 0.5882352941176471
# found player Gerard Piqué Bernabéu with a score of 0.7272727272727273
# found player Piqué with a score of 0.5882352941176471
# found player Mikel González de Martín Martínez with a score of 0.5957446808510638
# found player Mikel Gonzalez with a score of 0.9285714285714286
# found player Mikel González de Martín Martínez with a score of 0.5957446808510638
# found player Mikel Gonzalez with a score of 0.9285714285714286
# found player Pedro López Muñoz with a score of 0.2857142857142857
# found player Toño with a score of 1.0
# found player Pedro López Muñoz with a score of 0.2857142857142857
# found player Toño with a score of 1.0
# found player Alexis Ruano Delgado with a score of 0.46153846153846156
# found player Alexis with a score of 1.0
# found player Alexis Ruano Delgado with a score of 0.46153846153846156
# found player Alexis with a score of 1.0
# found player José Ángel Crespo Rincón with a score of 0.8292682926829268
# found player Jose Carlos with a score of 0.5714285714285714
# found player José Ángel Crespo Rincón with a score of 0.8292682926829268
# found player Jose Carlos with a score of 0.5714285714285714
# found player Andreu Fontàs Prat with a score of 0.8387096774193549
# found player Fontàs with a score of 0.631578947368421
# found player Andreu Fontàs Prat with a score of 0.8387096774193549
# found player Fontàs with a score of 0.631578947368421
# found player Daniel Carvajal Ramos with a score of 0.7647058823529411
# found player Carvajal with a score of 0.7619047619047619
# found player Daniel Carvajal Ramos with a score of 0.7647058823529411
# found player Carvajal with a score of 0.7619047619047619
# found player Allan-Roméo Nyom with a score of 0.7692307692307693
# found player A. Nyom with a score of 0.7058823529411765
# found player Allan-Roméo Nyom with a score of 0.7692307692307693
# found player A. Nyom with a score of 0.7058823529411765
# found player Benoît Trémoulinas with a score of 1.0
# found player B. Trémoulinas with a score of 0.8125
# found player Benoît Trémoulinas with a score of 1.0
# found player B. Trémoulinas with a score of 0.8125
# found player Eneko Bóveda Altube with a score of 0.7741935483870968
# found player Bóveda with a score of 0.6666666666666666
# found player Eneko Bóveda Altube with a score of 0.7741935483870968
# found player Bóveda with a score of 0.6666666666666666
# found player Rubén Ramiro Pastor with a score of 0.2608695652173913
# found player Tito with a score of 1.0
# found player Rubén Ramiro Pastor with a score of 0.2608695652173913
# found player Tito with a score of 1.0
# found player Noureddine Amrabat with a score of 0.875
# found player N. Amrabat with a score of 0.75
# found player Noureddine Amrabat with a score of 0.875
# found player N. Amrabat with a score of 0.75
# found player Joaquín Navarro Jiménez with a score of 0.5142857142857142
# found player Ximo Navarro with a score of 1.0
# found player Joaquín Navarro Jiménez with a score of 0.5142857142857142
# found player Ximo Navarro with a score of 1.0
# found player Shkodran Mustafi with a score of 1.0
# found player S. Mustafi with a score of 0.6923076923076923
# found player Shkodran Mustafi with a score of 1.0
# found player S. Mustafi with a score of 0.6923076923076923
# found player Víctor Sánchez Mata with a score of 0.8484848484848485
# found player Victor Sánchez with a score of 0.9285714285714286
# found player Víctor Sánchez Mata with a score of 0.8484848484848485
# found player Victor Sánchez with a score of 0.9285714285714286
# found player Aleksandar Pantić with a score of 1.0
# found player A. Pantic with a score of 0.5384615384615384
# found player Aleksandar Pantić with a score of 1.0
# found player A. Pantic with a score of 0.5384615384615384
# found player Diego Roberto Godín Leal with a score of 0.6285714285714286
# found player D. Godín with a score of 0.7368421052631579
# found player Diego Roberto Godín Leal with a score of 0.6285714285714286
# found player D. Godín with a score of 0.7368421052631579
# found player Gerard Piqué Bernabéu with a score of 0.7272727272727273
# found player Piqué with a score of 0.5882352941176471
# found player Gerard Piqué Bernabéu with a score of 0.7272727272727273
# found player Piqué with a score of 0.5882352941176471
# found player Iván López Mendoza with a score of 0.7142857142857143
# found player Pedro López with a score of 0.5714285714285714
# found player Iván López Mendoza with a score of 0.7142857142857143
# found player Pedro López with a score of 0.5714285714285714
# found player Allan-Roméo Nyom with a score of 0.7692307692307693
# found player A. Nyom with a score of 0.7058823529411765
# found player Allan-Roméo Nyom with a score of 0.7692307692307693
# found player A. Nyom with a score of 0.7058823529411765
# found player Damián Nicolás Suárez Suárez with a score of 0.6341463414634146
# found player D. Suárez with a score of 0.7272727272727273
# found player Damián Nicolás Suárez Suárez with a score of 0.6341463414634146
# found player D. Suárez with a score of 0.7272727272727273
# found player Juan Carlos Real Ruiz with a score of 0.41379310344827586
# found player Juanfran with a score of 1.0
# found player Juan Carlos Real Ruiz with a score of 0.41379310344827586
# found player Juanfran with a score of 1.0
# found player Mario Gaspar Pérez Martínez with a score of 0.6153846153846154
# found player Mario Gaspar with a score of 1.0
# found player Mario Gaspar Pérez Martínez with a score of 0.6153846153846154
# found player Mario Gaspar with a score of 1.0
# found player Mikel González de Martín Martínez with a score of 0.5957446808510638
# found player Mikel Gonzalez with a score of 0.9285714285714286
# found player Mikel González de Martín Martínez with a score of 0.5957446808510638
# found player Mikel Gonzalez with a score of 0.9285714285714286
# found player Aymeric Laporte with a score of 1.0
# found player A. Laporte with a score of 0.72
# found player Aymeric Laporte with a score of 1.0
# found player A. Laporte with a score of 0.72
# found player Rubén Ramiro Pastor with a score of 0.2608695652173913
# found player Tito with a score of 1.0
# found player Rubén Ramiro Pastor with a score of 0.2608695652173913
# found player Tito with a score of 1.0
# found player Daniel Carvajal Ramos with a score of 0.7647058823529411
# found player Carvajal with a score of 0.7619047619047619
# found player Daniel Carvajal Ramos with a score of 0.7647058823529411
# found player Carvajal with a score of 0.7619047619047619
# found player Hugo Mallo Novegil with a score of 0.7142857142857143
# found player Hugo Mallo with a score of 1.0
# found player Hugo Mallo Novegil with a score of 0.7142857142857143
# found player Hugo Mallo with a score of 1.0
# found player Eneko Bóveda Altube with a score of 0.7741935483870968
# found player Bóveda with a score of 0.6666666666666666
# found player Eneko Bóveda Altube with a score of 0.7741935483870968
# found player Bóveda with a score of 0.6666666666666666
# found player Noureddine Amrabat with a score of 0.875
# found player N. Amrabat with a score of 0.75
# found player Noureddine Amrabat with a score of 0.875
# found player N. Amrabat with a score of 0.75
# found player Víctor Guillermo Álvarez Delgado with a score of 0.6086956521739131
# found player Víctor Álvarez with a score of 1.0
# found player Víctor Guillermo Álvarez Delgado with a score of 0.6086956521739131
# found player Víctor Álvarez with a score of 1.0
# found player Filipe Augusto Carvalho Souza with a score of 0.6511627906976745
# found player Filipe Augusto with a score of 1.0
# found player Filipe Augusto Carvalho Souza with a score of 0.6511627906976745
# found player Filipe Augusto with a score of 1.0
# found player Benoît Trémoulinas with a score of 1.0
# found player B. Trémoulinas with a score of 0.8125
# found player Benoît Trémoulinas with a score of 1.0
# found player B. Trémoulinas with a score of 0.8125
# found player Joaquín Navarro Jiménez with a score of 0.5142857142857142
# found player Ximo Navarro with a score of 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_106068\1333768337.py in ?()
#      52
#      53     print(not_found)
#      54     for key in names_fix.keys():
#      55         curr_players['Club Name'].replace(names_fix[key],key, inplace=True)
# ---> 56     season = pipeline(curr_df, curr_players)
#      57     season['league'] = league
#      58     season.to_csv("season_data/season"+year+'.csv')
#      59
#
# ~\AppData\Local\Temp\ipykernel_106068\2392306672.py in ?(matches_df, ratings_df)
#     113
#     114
#     115     # Sanity Check
#     116     ratings_df = ratings_df[['Full Name', 'Club Name', 'Known As']+ att_list]
# --> 117     ratings_col(matches_df, ratings_df)
#     118     replace_nas(matches_df)
#     119     final_cols = ['home_score', 'home_team_name', 'away_score', 'away_team_name','home_GD_prior', 'away_GD_prior', 'home_Points_prior', 'away_Points_prior',
#     120                    'home_GD_form', 'home_Points_form', 'away_GD_form','away_Points_form', 'B365A', 'B365D', 'B365H',
#
# ~\AppData\Local\Temp\ipykernel_106068\2392306672.py in ?(df, att_df)
#      54
#      55
#      56             # Add columns for away team players
#      57             for att in attributes:
# ---> 58                 df[away_col + "_" + att] = df.apply(
#      59                     lambda row: 0 if pd.isna(row[away_col]) else
#      60                     (find_player(row[away_col], row['away_team_name'], att_df, attributes)[att]
#      61                     if find_player(row[away_col], row['away_team_name'], att_df, attributes) is not None else None),
#
# c:\Users\Yuval\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10370             engine_kwargs=engine_kwargs,
#   10371             args=args,
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#
# c:\Users\Yuval\anaconda3\Lib\site-packages\pandas\core\apply.py in ?(self)
#     912         # raw
#     913         elif self.raw:
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#
# c:\Users\Yuval\anaconda3\Lib\site-packages\pandas\core\apply.py in ?(self)
#    1061     def apply_standard(self):
#    1062         if self.engine == "python":
# -> 1063             results, res_index = self.apply_series_generator()
#    1064         else:
#    1065             results, res_index = self.apply_series_numba()
#    1066
#
# c:\Users\Yuval\anaconda3\Lib\site-packages\pandas\core\apply.py in ?(self)
#    1077
#    1078         with option_context("mode.chained_assignment", None):
#    1079             for i, v in enumerate(series_gen):
#    1080                 # ignore SettingWithCopy here in case the user mutates
# -> 1081                 results[i] = self.func(v, *self.args, **self.kwargs)
#    1082                 if isinstance(results[i], ABCSeries):
#    1083                     # If we have a view on v, we need to make a copy because
#    1084                     #  series_generator will swap out the underlying data
#
# ~\AppData\Local\Temp\ipykernel_106068\2392306672.py in ?(row)
#      59                     lambda row: 0 if pd.isna(row[away_col]) else
#
# ~\AppData\Local\Temp\ipykernel_106068\2392306672.py in ?(player_name, club_name, df, attributes)
#      12 def find_player(player_name, club_name,  df, attributes):
#      13     #first we filter by club name
# ---> 14     temp = df[df['Club Name'] == club_name]
#      15
#      16     #Now we find the player
#      17     sim_name, full_score = find_most_similar_name(player_name, temp['Full Name'])
#
# c:\Users\Yuval\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4089             return self.where(key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
# -> 4093             return self._getitem_bool_array(key)
#    4094
#    4095         # We are left with two options: a single key, and a collection of keys,
#    4096         # We interpret tuples as collections only for non-MultiIndex
#
# c:\Users\Yuval\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4150
#    4151         if key.all():
#    4152             return self.copy(deep=None)
#    4153
# -> 4154         indexer = key.nonzero()[0]
#    4155         return self._take_with_is_copy(indexer, axis=0)
#
# KeyboardInterrupt:

# %%
### fixing columns

for year in years:
    curr = pd.read_csv('season_data/season'+year+'.csv')
    for col in curr.columns:
        if ('Home' in col or 'Away' in col) and 'Overall' not in col:
            curr.drop(col, axis=1, inplace=True)
    curr.drop('matchweek_num', axis=1,inplace=True)
    curr.rename(columns = {'matchweek' : 'Matchweek'},inplace=True)
    epl_curr = pd.read_csv("epl_data(fully_proccessed)/epl"+year+"_proccessed_with_form.csv")
    epl_curr = epl_curr[curr.columns]
    curr = pd.concat([curr, epl_curr],axis=0, ignore_index=True)
    curr.drop(['Unnamed: 0.1','Unnamed: 0'], axis=1, inplace=True)
    curr.to_csv("season_data/season"+year+"_proccessed.csv")
